# %%
import pandas as pd
import plotly
import plotly.graph_objs as go

# %%
hourly = pd.read_csv("data/hourly_data.csv")
# Out:
# /Users/chengcheng/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning:
#
# Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
hourly
# Out:
#         Year  Month    Weekday  Hour destination  num_riders  \
# 0       2011      1     Friday     0        12TH    3.312500
# 1       2011      1     Friday     4        12TH    1.365079
# 2       2011      1     Friday     5        12TH    4.036232
# 3       2011      1     Friday     6        12TH   15.133758
# 4       2011      1     Friday     7        12TH   41.210526
# 5       2011      1     Friday     8        12TH   57.176471
# 6       2011      1     Friday     9        12TH   34.111111
# 7       2011      1     Friday    10        12TH   14.696429
# 8       2011      1     Friday    11        12TH    9.934524
# 9       2011      1     Friday    12        12TH   10.092593
# 10      2011      1     Friday    13        12TH   10.444444
# 11      2011      1     Friday    14        12TH   10.086957
# 12      2011      1     Friday    15        12TH   10.518750
# 13      2011      1     Friday    16        12TH   12.726708
# ...

# %%
hourly_tmp = hourly[(hourly['Year'] == 2011) & (hourly['Month'] == 1)]

# %%
hourly_tmp['Weekday'].unique()
# Out:
# array(['Friday', 'Monday', 'Saturday', 'Sunday', 'Thursday', 'Tuesday',
#        'Wednesday'], dtype=object)

# %%
result = hourly_tmp.groupby(['Weekday','Hour'])['num_riders'].mean()

# %%
z_data = []
for day in ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']:
    z_data.append(result[day].values)

# %%
trace = go.Heatmap(z=z_data,
                   x=['12AM', '1AM', '2AM', '3AM', '4AM', '5AM', '6AM', '7AM', '8AM', '9AM',
                     '10AM', '11AM', '12PM', '1PM', '2PM', '3PM', '4PM', '5PM', '6PM', '7PM',
                     '8PM', '9PM', '10PM', '11PM'],
                   y=['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'])
data=[trace]

# %%
layout = go.Layout()

# %%
updatemenus=list([
    dict(
        buttons=list([   
            dict(
                args=['type', 'surface'],
                label='3D Surface',
                method='restyle'
            ),
            dict(
                args=['type', 'heatmap'],
                label='Heatmap',
                method='restyle'
            )             
        ]),
        direction = 'down',
        pad = {'r': 10, 't': 10},
        showactive = True,
        x = 0.1,
        xanchor = 'left',
        y = 1.1,
        yanchor = 'top' 
    ),
])

# %%
layout['updatemenus'] = updatemenus
fig = dict(data=data, layout=layout)
plotly.offline.plot(fig)
# Out:
# 'file:///Users/chengcheng/Desktop/MSAN_2018_SP_2/Data Viz/bart-data-visualization/temp-plot.html'
